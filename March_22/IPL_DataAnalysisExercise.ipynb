# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
matches = pd.read_csv('ipldata/IPL Matches 2008-2020.csv')
deliveries = pd.read_csv('ipldata/IPL Ball-by-Ball 2008-2020.csv')

# %%
matches.head()
# Out:
#        id        city        date player_of_match  \
# 0  335982   Bangalore  2008-04-18     BB McCullum
# 1  335983  Chandigarh  2008-04-19      MEK Hussey
# 2  335984       Delhi  2008-04-19     MF Maharoof
# 3  335985      Mumbai  2008-04-20      MV Boucher
# 4  335986     Kolkata  2008-04-20       DJ Hussey
#
#                                         venue  neutral_venue  \
# 0                       M Chinnaswamy Stadium              0
# 1  Punjab Cricket Association Stadium, Mohali              0
# 2                            Feroz Shah Kotla              0
# 3                            Wankhede Stadium              0
# 4                                Eden Gardens              0
#
#                          team1                        team2  \
# 0  Royal Challengers Bangalore        Kolkata Knight Riders
# 1              Kings XI Punjab          Chennai Super Kings
# 2             Delhi Daredevils             Rajasthan Royals
# ...

# %%
matches.shape
# Out:
# (816, 17)

# %%
deliveries.shape
# Out:
# (193468, 18)

# %%
# Show winning count of each team
# Out:
# Mumbai Indians                 120
# Chennai Super Kings            106
# Kolkata Knight Riders           99
# Royal Challengers Bangalore     91
# Kings XI Punjab                 88
# Rajasthan Royals                81
# Delhi Daredevils                67
# Sunrisers Hyderabad             66
# Deccan Chargers                 29
# Delhi Capitals                  19
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
# Plot winning count of each team

# %%
# Plot winning count of each team using seaborn

# %%
# show toss decision count of field and bat

# %%
toss_decision
# Out:
# field    496
# bat      320
# Name: toss_decision, dtype: int64

# %%
# Plot pie chart to show toss decision of field and bat

# %%
# Plot toss decision and compare count of field and bat per year

# %%
# plot top 10 batsmen based on run they have scored in total so far
# Out:
# <AxesSubplot:xlabel='batsman'>
