# %%
import pandas as pd

# %%
df = pd.read_csv('30_Auto_theft.csv')

# %%
df.shape
# Out:
# (1865, 7)

# %%
df.head()
# Out:
#                    Area_Name  Year                  Group_Name  \
# 0  Andaman & Nicobar Islands  2001  AT1-Motor Cycles/ Scooters
# 1             Andhra Pradesh  2001  AT1-Motor Cycles/ Scooters
# 2          Arunachal Pradesh  2001  AT1-Motor Cycles/ Scooters
# 3                      Assam  2001  AT1-Motor Cycles/ Scooters
# 4                      Bihar  2001  AT1-Motor Cycles/ Scooters
#
#               Sub_Group_Name  Auto_Theft_Coordinated/Traced  \
# 0  1. Motor Cycles/ Scooters                            NaN
# 1  1. Motor Cycles/ Scooters                          136.0
# 2  1. Motor Cycles/ Scooters                            0.0
# 3  1. Motor Cycles/ Scooters                            0.0
# 4  1. Motor Cycles/ Scooters                           44.0
#
#    Auto_Theft_Recovered  Auto_Theft_Stolen
# 0                   4.0                  4
# 1                1311.0               2725
# 2                  21.0                 27
# 3                  94.0                205
# ...

# %%
df.columns
# Out:
# Index(['Area_Name', 'Year', 'Group_Name', 'Sub_Group_Name',
#        'Auto_Theft_Coordinated/Traced', 'Auto_Theft_Recovered',
#        'Auto_Theft_Stolen'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1865 entries, 0 to 1864
# Data columns (total 7 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Area_Name                      1865 non-null   object
#  1   Year                           1865 non-null   int64
#  2   Group_Name                     1865 non-null   object
#  3   Sub_Group_Name                 1865 non-null   object
#  4   Auto_Theft_Coordinated/Traced  1519 non-null   float64
#  5   Auto_Theft_Recovered           1837 non-null   float64
#  6   Auto_Theft_Stolen              1865 non-null   int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 102.1+ KB

# %%
df.isna().sum()
# Out:
# Area_Name                          0
# Year                               0
# Group_Name                         0
# Sub_Group_Name                     0
# Auto_Theft_Coordinated/Traced    346
# Auto_Theft_Recovered              28
# Auto_Theft_Stolen                  0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Auto_Theft_Coordinated/Traced  Auto_Theft_Recovered  \
# count  1865.000000                    1519.000000           1837.000000
# mean   2005.564075                      74.541145            297.927055
# std       2.853598                     270.195127            677.445512
# min    2001.000000                       0.000000              0.000000
# 25%    2003.000000                       0.000000              4.000000
# 50%    2006.000000                       2.000000             29.000000
# 75%    2008.000000                      27.000000            177.000000
# max    2010.000000                    2985.000000           5453.000000
#
#        Auto_Theft_Stolen
# count        1865.000000
# mean         1029.431635
# std          2399.389932
# min             0.000000
# 25%             7.000000
# 50%            80.000000
# 75%           521.000000
# max         18605.000000

# %%
df.isnull().sum()
# Out:
# Area_Name                          0
# Year                               0
# Group_Name                         0
# Sub_Group_Name                     0
# Auto_Theft_Coordinated/Traced    346
# Auto_Theft_Recovered              28
# Auto_Theft_Stolen                  0
# dtype: int64

# %%
pd.value_counts(df['Year'])
# Out:
# 2008    192
# 2009    192
# 2007    190
# 2006    189
# 2004    188
# 2005    188
# 2010    187
# 2003    186
# 2001    177
# 2002    176
# Name: Year, dtype: int64

# %%
pd.value_counts(df['Group_Name'])
# Out:
# AT6-Total                                         344
# AT1-Motor Cycles/ Scooters                        341
# AT2-Motor Car/Taxi/Jeep                           331
# AT5-Other Motor vehicles                          303
# AT4-Goods carrying vehicles (Trucks/Tempo etc)    292
# AT3-Buses                                         254
# Name: Group_Name, dtype: int64

# %%
df['Auto_Theft_Stolen'].max()
# Out:
# 18605

# %%
df.sort_values(by='Auto_Theft_Stolen').head()
# Out:
#      Area_Name  Year Group_Name Sub_Group_Name  Auto_Theft_Coordinated/Traced  \
# 762   Nagaland  2004  AT3-Buses       3. Buses                            0.0
# 868   Nagaland  2008  AT3-Buses       3. Buses                            0.0
# 867    Mizoram  2008  AT3-Buses       3. Buses                            0.0
# 866  Meghalaya  2008  AT3-Buses       3. Buses                            0.0
# 865    Manipur  2008  AT3-Buses       3. Buses                            0.0
#
#      Auto_Theft_Recovered  Auto_Theft_Stolen
# 762                   0.0                  0
# 868                   0.0                  0
# 867                   0.0                  0
# 866                   0.0                  0
# 865                   0.0                  0

# %%
df.sort_values(by='Auto_Theft_Stolen', ascending=False).head()
# Out:
#           Area_Name  Year                  Group_Name  \
# 1850    Maharashtra  2010                   AT6-Total
# 1816    Maharashtra  2009                   AT6-Total
# 1781    Maharashtra  2008                   AT6-Total
# 1862  Uttar Pradesh  2010                   AT6-Total
# 326     Maharashtra  2010  AT1-Motor Cycles/ Scooters
#
#                    Sub_Group_Name  Auto_Theft_Coordinated/Traced  \
# 1850  6. Total (Sum of 1-5 Above)                         1266.0
# 1816  6. Total (Sum of 1-5 Above)                         1473.0
# 1781  6. Total (Sum of 1-5 Above)                          875.0
# 1862  6. Total (Sum of 1-5 Above)                          505.0
# 326     1. Motor Cycles/ Scooters                          932.0
#
#       Auto_Theft_Recovered  Auto_Theft_Stolen
# 1850                4641.0              18605
# 1816                4615.0              18236
# 1781                3334.0              16909
# 1862                2434.0              16705
# ...

# %%
# df.sort_values(by='Auto_Theft_Stolen', ascending=False).head().sort_values(by='Auto_Theft_Recovered')

# %%
df['Auto_Theft_Stolen'].sum()
# Out:
# 1919890

# %%
df.groupby('Year')['Auto_Theft_Recovered'].sum()
# Out:
# Year
# 2001    41588.0
# 2002    44060.0
# 2003    45620.0
# 2004    50728.0
# 2005    49836.0
# 2006    52948.0
# 2007    56252.0
# 2008    58768.0
# 2009    71090.0
# 2010    76402.0
# Name: Auto_Theft_Recovered, dtype: float64

# %%
df.groupby(['Year','Group_Name'])['Auto_Theft_Recovered'].sum()
# Out:
# Year  Group_Name
# 2001  AT1-Motor Cycles/ Scooters                        14568.0
#       AT2-Motor Car/Taxi/Jeep                            4379.0
#       AT3-Buses                                           120.0
#       AT4-Goods carrying vehicles (Trucks/Tempo etc)      419.0
#       AT5-Other Motor vehicles                           1308.0
#       AT6-Total                                         20794.0
# 2002  AT1-Motor Cycles/ Scooters                        15863.0
#       AT2-Motor Car/Taxi/Jeep                            4234.0
#       AT3-Buses                                           109.0
#       AT4-Goods carrying vehicles (Trucks/Tempo etc)      516.0
#       AT5-Other Motor vehicles                           1308.0
#       AT6-Total                                         22030.0
# 2003  AT1-Motor Cycles/ Scooters                        16674.0
#       AT2-Motor Car/Taxi/Jeep                            4196.0
# ...

# %%
df.groupby(['Year','Group_Name'])['Auto_Theft_Recovered'].sum().reset_index().head()
# Out:
#    Year                                      Group_Name  Auto_Theft_Recovered
# 0  2001                      AT1-Motor Cycles/ Scooters               14568.0
# 1  2001                         AT2-Motor Car/Taxi/Jeep                4379.0
# 2  2001                                       AT3-Buses                 120.0
# 3  2001  AT4-Goods carrying vehicles (Trucks/Tempo etc)                 419.0
# 4  2001                        AT5-Other Motor vehicles                1308.0

# %%
df.groupby(['Year','Group_Name'])['Auto_Theft_Recovered'].sum().reset_index().sort_values('Auto_Theft_Recovered', 
                                                                                          ascending=False)
# Out:
#     Year                                      Group_Name  Auto_Theft_Recovered
# 59  2010                                       AT6-Total               38201.0
# 53  2009                                       AT6-Total               35545.0
# 54  2010                      AT1-Motor Cycles/ Scooters               30404.0
# 47  2008                                       AT6-Total               29384.0
# 48  2009                      AT1-Motor Cycles/ Scooters               28703.0
# 41  2007                                       AT6-Total               28126.0
# 35  2006                                       AT6-Total               26474.0
# 23  2004                                       AT6-Total               25364.0
# 29  2005                                       AT6-Total               24918.0
# 42  2008                      AT1-Motor Cycles/ Scooters               23439.0
# 17  2003                                       AT6-Total               22810.0
# ...

# %%
temp_df = df.groupby(['Year','Group_Name'])['Auto_Theft_Recovered'].sum().reset_index().sort_values('Auto_Theft_Recovered', 
                                                                                          ascending=False)

# %%
temp_df.head()
# Out:
#     Year                  Group_Name  Auto_Theft_Recovered
# 59  2010                   AT6-Total               38201.0
# 53  2009                   AT6-Total               35545.0
# 54  2010  AT1-Motor Cycles/ Scooters               30404.0
# 47  2008                   AT6-Total               29384.0
# 48  2009  AT1-Motor Cycles/ Scooters               28703.0

# %%
pd.pivot_table(temp_df, values='Auto_Theft_Recovered', index='Year', columns='Group_Name', aggfunc='sum')
# Out:
# Group_Name  AT1-Motor Cycles/ Scooters  AT2-Motor Car/Taxi/Jeep  AT3-Buses  \
# Year
# 2001                           14568.0                   4379.0      120.0
# 2002                           15863.0                   4234.0      109.0
# 2003                           16674.0                   4196.0       96.0
# 2004                           18932.0                   3946.0       97.0
# 2005                           19140.0                   3589.0      114.0
# 2006                           20165.0                   3645.0      134.0
# 2007                           21448.0                   3688.0      125.0
# 2008                           23439.0                   3514.0       91.0
# 2009                           28703.0                   4351.0       42.0
# 2010                           30404.0                   4969.0       90.0
#
# Group_Name  AT4-Goods carrying vehicles (Trucks/Tempo etc)  \
# Year
# 2001                                                 419.0
# ...

# %%
# pd.pivot_table(df, values=['J','K'], index=['A','B'], columns=['C','D'], aggfunc={'J' : np.mean, 'K' : np.sum})
