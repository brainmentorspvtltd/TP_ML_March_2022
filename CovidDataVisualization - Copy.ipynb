# %%
import urllib.request as url
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = "https://data.covid19india.org/states_daily.json"
response = url.urlopen(path)

# %%
data = json.load(response)

# %%
type(data)
# Out:
# dict

# %%
states = data['states_daily']
df = pd.DataFrame(states)

# %%
df.head()
# Out:
#   an ap ar as br ch ct       date     dateymd dd  ... sk     status tg tn tr  \
# 0  0  1  0  0  0  0  0  14-Mar-20  2020-03-14  0  ...  0  Confirmed  1  1  0
# 1  0  0  0  0  0  0  0  14-Mar-20  2020-03-14  0  ...  0  Recovered  0  0  0
# 2  0  0  0  0  0  0  0  14-Mar-20  2020-03-14  0  ...  0   Deceased  0  0  0
# 3  0  0  0  0  0  0  0  15-Mar-20  2020-03-15  0  ...  0  Confirmed  2  0  0
# 4  0  0  0  0  0  0  0  15-Mar-20  2020-03-15  0  ...  0  Recovered  1  0  0
#
#    tt un  up ut wb
# 0  81  0  12  0  0
# 1   9  0   4  0  0
# 2   2  0   0  0  0
# 3  27  0   1  0  0
# 4   4  0   0  0  0
#
# [5 rows x 42 columns]

# %%
df['date'][0]
# Out:
# '14-Mar-20'

# %%
df['dateymd'][0]
# Out:
# '2020-03-14'

# %%
df['dateymd'] = pd.to_datetime(df['dateymd'])

# %%
df['dateymd'][0]
# Out:
# Timestamp('2020-03-14 00:00:00')

# %%
df['dl'][0]
# Out:
# '7'

# %%
df['dl'] = df['dl'].astype('int')
df['mh'] = df['mh'].astype('int')
df['rj'] = df['rj'].astype('int')
df['hr'] = df['hr'].astype('int')
df['up'] = df['up'].astype('int')
df['tt'] = df['tt'].astype('int')

# %%
df['dl'][0]
# Out:
# 7

# %%
confirmed_df = df[df['status'] == 'Confirmed']
recovered_df = df[df['status'] == 'Recovered']
deceased_df = df[df['status'] == 'Deceased']

# %%
confirmed_df.head()
# Out:
#    an ap ar as br ch ct       date    dateymd dd  ...  sk     status tg tn tr  \
# 0   0  1  0  0  0  0  0  14-Mar-20 2020-03-14  0  ...   0  Confirmed  1  1  0
# 3   0  0  0  0  0  0  0  15-Mar-20 2020-03-15  0  ...   0  Confirmed  2  0  0
# 6   0  0  0  0  0  0  0  16-Mar-20 2020-03-16  0  ...   0  Confirmed  1  0  0
# 9   0  0  0  0  0  0  0  17-Mar-20 2020-03-17  0  ...   0  Confirmed  1  0  0
# 12  0  0  0  0  0  0  0  18-Mar-20 2020-03-18  0  ...   0  Confirmed  8  1  0
#
#     tt un  up ut wb
# 0   81  0  12  0  0
# 3   27  0   1  0  0
# 6   15  0   0  1  0
# 9   11  0   2  0  1
# 12  37  0   2  1  0
#
# [5 rows x 42 columns]

# %%
confirmed_df.shape
# Out:
# (521, 42)

# %%
top_10[['dateymd','dl']]
# Out:
#         dateymd     dl
# 1254 2021-05-06  19133
# 1251 2021-05-05  20960
# 1257 2021-05-07  19832
# 1260 2021-05-08  17364
# 1236 2021-04-30  27047
# 1239 2021-05-01  25219
# 1233 2021-04-29  24235
# 1248 2021-05-04  19953
# 1230 2021-04-28  25986
# 1242 2021-05-02  20394
